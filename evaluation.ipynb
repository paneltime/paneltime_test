# %%
import pandas as pd
rres = pd.read_csv('rresults.csv', sep=';')
rres = rres[rres['mu'].isna()==False]
rres
# Out:
#             mu       ar1       ar2       ma1       ma2    mxreg1    mxreg2  \
# 1     0.083211 -0.185627  0.347545 -0.362231  0.204188  0.992412  0.967467
# 2    -0.108186 -0.070975  0.456583 -0.487099  0.150766  1.016328  1.083682
# 3     0.184097 -0.364958  0.292182 -0.165939  0.235147  0.956606  1.061794
# 4    -0.088182 -0.233395  0.382607 -0.356741  0.202700  1.025668  0.976594
# 5     0.109775 -0.164640  0.479032 -0.359839  0.098817  0.983919  1.034389
# ...        ...       ...       ...       ...       ...       ...       ...
# 995  -0.119810 -0.243263  0.350572 -0.272689  0.178746  1.041896  1.066541
# 997  -0.045553 -0.184890  0.347731 -0.376480  0.179264  0.912571  0.941828
# 998   0.030278 -0.232110  0.312774 -0.278001  0.192078  1.060199  1.053904
# 999  -0.052283 -0.474512  0.183967 -0.108797  0.220372  0.897899  1.079250
# 1000 -0.046830 -0.469531  0.148662 -0.081006  0.225053  1.045250  1.009845
#
# ...

# %%
pres = pd.read_csv('paneltimeres.csv', sep=';')
pres = pres[pres['Intercept'].isna()==False]
pres
# Out:
#      Intercept        X0        X1  rho0    AR    p  rho1    AR    p  \
# 0     0.149982  1.003366  0.966854        -0.171392         0.349578
# 1    -0.195060  1.023445  1.076656        -0.161444         0.381092
# 2     0.251862  0.955844  1.061016        -0.426967         0.214736
# 3    -0.065734  1.024590  0.977261        -0.237457         0.382013
# 4     0.191809  0.981224  1.049691        -1.073106        -0.286702
# ..         ...       ...       ...              ...              ...
# 995  -0.102494  0.955086  0.975182        -0.328084         0.359802
# 996  -0.023677  0.911762  0.945312        -0.178036         0.335499
# 997  -0.003976  1.029797  1.073671        -0.803804        -0.087108
# 998  -0.053103  0.893168  1.076762        -0.455504         0.208241
# 999  -0.050998  1.048054  1.014041        -0.467622         0.154588
#
#      lambda0 MA    q  lambda1 MA    q  gamma0  GARCH k  gamma1  GARCH k  \
# ...

# %%
print(pres[['X0','X1']].mean())
print(pres[['X0','X1']].std())
# Out:
# X0    1.001844
# X1    0.997653
# dtype: float64
# X0    0.047538
# X1    0.047531
# dtype: float64

# %%
rres.mean()
print(rres[['mxreg1','mxreg2']].mean())
print(rres[['mxreg1','mxreg2']].std())
# Out:
# mxreg1    1.002004
# mxreg2    0.997595
# dtype: float64
# mxreg1    0.042012
# mxreg2    0.041914
# dtype: float64
